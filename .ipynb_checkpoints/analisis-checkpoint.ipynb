# %%
import pandas as pd
import glob
import matplotlib.pyplot as plt
import os
import numpy as np

# %% [markdown]
# # Carga de datos

# %%
path = os.getcwd()

denuncias_2017 = pd.read_csv('/Users/martina/Documents/MVT_Data/Denuncias_2017.csv')

denuncias_2018_01 = pd.read_csv('/Users/martina/Documents/MVT_Data/Denuncias_2018_01.csv')
denuncias_2018_02 = pd.read_csv('/Users/martina/Documents/MVT_Data/Denuncias_2018_02.csv')
denuncias_2018_03 = pd.read_csv('/Users/martina/Documents/MVT_Data/Denuncias_2018_03.csv')
denuncias_2018_04 = pd.read_csv('/Users/martina/Documents/MVT_Data/Denuncias_2018_04.csv')
denuncias_2018_05 = pd.read_csv('/Users/martina/Documents/MVT_Data/Denuncias_2018_05.csv')
denuncias_2018_06 = pd.read_csv('/Users/martina/Documents/MVT_Data/Denuncias_2018_06.csv')
denuncias_2018_07 = pd.read_csv('/Users/martina/Documents/MVT_Data/Denuncias_2018_07.csv')
denuncias_2018_08 = pd.read_csv('/Users/martina/Documents/MVT_Data/Denuncias_2018_08.csv')
denuncias_2018_09 = pd.read_csv('/Users/martina/Documents/MVT_Data/Denuncias_2018_09.csv')
denuncias_2018_10 = pd.read_csv('/Users/martina/Documents/MVT_Data/Denuncias_2018_10.csv')
denuncias_2018_11 = pd.read_csv('/Users/martina/Documents/MVT_Data/Denuncias_2018_11.csv')
denuncias_2018_12 = pd.read_csv('/Users/martina/Documents/MVT_Data/Denuncias_2018_12.csv')

denuncias_2019_01 = pd.read_csv('/Users/martina/Documents/MVT_Data/Denuncias_2019_01.csv')
denuncias_2019_02 = pd.read_csv('/Users/martina/Documents/MVT_Data/Denuncias_2019_02.csv')
denuncias_2019_03 = pd.read_csv('/Users/martina/Documents/MVT_Data/Denuncias_2019_03.csv')
denuncias_2019_04 = pd.read_csv('/Users/martina/Documents/MVT_Data/Denuncias_2019_04.csv')
denuncias_2019_05 = pd.read_csv('/Users/martina/Documents/MVT_Data/Denuncias_2019_05.csv')
denuncias_2019_06 = pd.read_csv('/Users/martina/Documents/MVT_Data/Denuncias_2019_06.csv')
denuncias_2019_07 = pd.read_csv('/Users/martina/Documents/MVT_Data/Denuncias_2019_07.csv')
denuncias_2019_08 = pd.read_csv('/Users/martina/Documents/MVT_Data/Denuncias_2019_08.csv')
denuncias_2019_09 = pd.read_csv('/Users/martina/Documents/MVT_Data/Denuncias_2019_09.csv')
denuncias_2019_10 = pd.read_csv('/Users/martina/Documents/MVT_Data/Denuncias_2019_10.csv')

denuncias = [denuncias_2017, denuncias_2018_01, denuncias_2018_02, denuncias_2018_03, 
             denuncias_2018_04, denuncias_2018_05, denuncias_2018_06, denuncias_2018_07,
             denuncias_2018_08, denuncias_2018_09, denuncias_2018_10, denuncias_2018_11,
             denuncias_2018_12, denuncias_2019_01, denuncias_2019_02, denuncias_2019_03,
             denuncias_2019_04, denuncias_2019_05, denuncias_2019_06, denuncias_2019_07,
             denuncias_2019_08, denuncias_2019_09, denuncias_2019_10]

# %% [markdown]
# # Limpieza
# ## Estandarizar columnas

# %%
# Sabemos los momentos en los que hay cambios en los nombres de las columnas
change_dates = [denuncias_2017, denuncias_2018_01, denuncias_2018_06, denuncias_2018_07, denuncias_2019_01, 
                denuncias_2019_05]

denuncias_2017.name = 'denuncias_2017'
denuncias_2018_01.name = 'denuncias_2018_01'
denuncias_2018_06.name = 'denuncias_2018_06'
denuncias_2018_07.name = 'denuncias_2018_07'
denuncias_2019_01.name = 'denuncias_2019_01'
denuncias_2019_05.name = 'denuncias_2019_05'

# uno los nombres de columnas de todos los dataframes

column_names = []

for period in change_dates:
    for col in period.columns:
        if col not in column_names:
            column_names.append(col)
            
# ahora veo cuales dataframes tienen cada columna

for col in column_names:
    for period in change_dates:
        if col in period.columns:
            print(period.name + ': True')
        else:
            print(period.name + ': False')

# Se podria convertir esta serie de prints en un df
# Out:
# denuncias_2017: True
# denuncias_2018_01: True
# denuncias_2018_06: True
# denuncias_2018_07: True
# denuncias_2019_01: True
# denuncias_2019_05: True
# denuncias_2017: True
# denuncias_2018_01: True
# denuncias_2018_06: True
# denuncias_2018_07: True
# denuncias_2019_01: True
# denuncias_2019_05: True
# denuncias_2017: True
# denuncias_2018_01: True
# denuncias_2018_06: True
# denuncias_2018_07: True
# denuncias_2019_01: True
# denuncias_2019_05: True
# denuncias_2017: True
# denuncias_2018_01: False
# denuncias_2018_06: False
# denuncias_2018_07: False
# denuncias_2019_01: False
# denuncias_2019_05: False
# denuncias_2017: True
# denuncias_2018_01: False
# denuncias_2018_06: False
# denuncias_2018_07: False
# denuncias_2019_01: False
# denuncias_2019_05: False
# denuncias_2017: True
# denuncias_2018_01: True
# denuncias_2018_06: True
# denuncias_2018_07: False
# denuncias_2019_01: False
# denuncias_2019_05: False
# denuncias_2017: True
# denuncias_2018_01: False
# denuncias_2018_06: False
# denuncias_2018_07: False
# denuncias_2019_01: False
# denuncias_2019_05: False
# denuncias_2017: True
# denuncias_2018_01: False
# denuncias_2018_06: False
# denuncias_2018_07: False
# denuncias_2019_01: False
# denuncias_2019_05: False
# denuncias_2017: True
# denuncias_2018_01: False
# denuncias_2018_06: False
# denuncias_2018_07: False
# denuncias_2019_01: False
# denuncias_2019_05: False
# denuncias_2017: True
# denuncias_2018_01: False
# denuncias_2018_06: False
# denuncias_2018_07: False
# denuncias_2019_01: False
# denuncias_2019_05: False
# denuncias_2017: False
# denuncias_2018_01: True
# denuncias_2018_06: True
# denuncias_2018_07: True
# denuncias_2019_01: True
# denuncias_2019_05: True
# denuncias_2017: False
# denuncias_2018_01: True
# denuncias_2018_06: True
# denuncias_2018_07: True
# denuncias_2019_01: True
# denuncias_2019_05: True
# denuncias_2017: False
# denuncias_2018_01: True
# denuncias_2018_06: True
# denuncias_2018_07: True
# denuncias_2019_01: True
# denuncias_2019_05: True
# denuncias_2017: False
# denuncias_2018_01: True
# denuncias_2018_06: True
# denuncias_2018_07: True
# denuncias_2019_01: True
# denuncias_2019_05: True
# denuncias_2017: False
# denuncias_2018_01: True
# denuncias_2018_06: True
# denuncias_2018_07: True
# denuncias_2019_01: True
# denuncias_2019_05: True
# denuncias_2017: False
# denuncias_2018_01: True
# denuncias_2018_06: True
# denuncias_2018_07: True
# denuncias_2019_01: True
# denuncias_2019_05: True
# denuncias_2017: False
# denuncias_2018_01: True
# denuncias_2018_06: True
# denuncias_2018_07: True
# denuncias_2019_01: True
# denuncias_2019_05: True
# denuncias_2017: False
# denuncias_2018_01: True
# denuncias_2018_06: True
# denuncias_2018_07: False
# denuncias_2019_01: False
# denuncias_2019_05: False
# denuncias_2017: False
# denuncias_2018_01: True
# denuncias_2018_06: True
# denuncias_2018_07: False
# denuncias_2019_01: False
# denuncias_2019_05: False
# denuncias_2017: False
# denuncias_2018_01: True
# denuncias_2018_06: True
# denuncias_2018_07: False
# denuncias_2019_01: False
# denuncias_2019_05: False
# denuncias_2017: False
# denuncias_2018_01: True
# denuncias_2018_06: True
# denuncias_2018_07: False
# denuncias_2019_01: False
# denuncias_2019_05: False
# denuncias_2017: False
# denuncias_2018_01: True
# denuncias_2018_06: True
# denuncias_2018_07: False
# denuncias_2019_01: False
# denuncias_2019_05: False
# denuncias_2017: False
# denuncias_2018_01: True
# denuncias_2018_06: True
# denuncias_2018_07: False
# denuncias_2019_01: False
# denuncias_2019_05: False
# denuncias_2017: False
# denuncias_2018_01: True
# denuncias_2018_06: True
# denuncias_2018_07: False
# denuncias_2019_01: False
# denuncias_2019_05: False
# denuncias_2017: False
# denuncias_2018_01: True
# denuncias_2018_06: True
# denuncias_2018_07: True
# denuncias_2019_01: True
# denuncias_2019_05: True
# denuncias_2017: False
# denuncias_2018_01: True
# denuncias_2018_06: True
# denuncias_2018_07: True
# denuncias_2019_01: True
# denuncias_2019_05: True
# denuncias_2017: False
# denuncias_2018_01: True
# denuncias_2018_06: True
# denuncias_2018_07: True
# denuncias_2019_01: True
# denuncias_2019_05: True
# denuncias_2017: False
# denuncias_2018_01: True
# denuncias_2018_06: True
# denuncias_2018_07: True
# denuncias_2019_01: True
# denuncias_2019_05: True
# denuncias_2017: False
# denuncias_2018_01: True
# denuncias_2018_06: True
# denuncias_2018_07: True
# denuncias_2019_01: True
# denuncias_2019_05: True
# denuncias_2017: False
# denuncias_2018_01: True
# denuncias_2018_06: True
# denuncias_2018_07: True
# denuncias_2019_01: True
# denuncias_2019_05: True
# denuncias_2017: False
# denuncias_2018_01: True
# denuncias_2018_06: True
# denuncias_2018_07: True
# denuncias_2019_01: True
# denuncias_2019_05: True
# denuncias_2017: False
# denuncias_2018_01: True
# denuncias_2018_06: True
# denuncias_2018_07: True
# denuncias_2019_01: True
# denuncias_2019_05: False
# denuncias_2017: False
# denuncias_2018_01: True
# denuncias_2018_06: True
# denuncias_2018_07: False
# denuncias_2019_01: False
# denuncias_2019_05: False
# denuncias_2017: False
# denuncias_2018_01: True
# denuncias_2018_06: True
# denuncias_2018_07: True
# denuncias_2019_01: True
# denuncias_2019_05: False
# denuncias_2017: False
# denuncias_2018_01: True
# denuncias_2018_06: True
# denuncias_2018_07: False
# denuncias_2019_01: False
# denuncias_2019_05: False
# denuncias_2017: False
# denuncias_2018_01: False
# denuncias_2018_06: True
# denuncias_2018_07: True
# denuncias_2019_01: True
# denuncias_2019_05: True
# denuncias_2017: False
# denuncias_2018_01: False
# denuncias_2018_06: False
# denuncias_2018_07: True
# denuncias_2019_01: True
# denuncias_2019_05: True
# denuncias_2017: False
# denuncias_2018_01: False
# denuncias_2018_06: False
# denuncias_2018_07: True
# denuncias_2019_01: True
# denuncias_2019_05: True
# denuncias_2017: False
# denuncias_2018_01: False
# denuncias_2018_06: False
# denuncias_2018_07: True
# denuncias_2019_01: True
# denuncias_2019_05: True
# denuncias_2017: False
# denuncias_2018_01: False
# denuncias_2018_06: False
# denuncias_2018_07: True
# denuncias_2019_01: True
# denuncias_2019_05: True
# denuncias_2017: False
# denuncias_2018_01: False
# denuncias_2018_06: False
# denuncias_2018_07: True
# denuncias_2019_01: True
# denuncias_2019_05: True
# denuncias_2017: False
# denuncias_2018_01: False
# denuncias_2018_06: False
# denuncias_2018_07: True
# denuncias_2019_01: True
# denuncias_2019_05: True
# denuncias_2017: False
# denuncias_2018_01: False
# denuncias_2018_06: False
# denuncias_2018_07: True
# denuncias_2019_01: True
# denuncias_2019_05: True
# denuncias_2017: False
# denuncias_2018_01: False
# denuncias_2018_06: False
# denuncias_2018_07: True
# denuncias_2019_01: True
# denuncias_2019_05: True
# denuncias_2017: False
# denuncias_2018_01: False
# denuncias_2018_06: False
# denuncias_2018_07: True
# denuncias_2019_01: True
# denuncias_2019_05: True
# denuncias_2017: False
# denuncias_2018_01: False
# denuncias_2018_06: False
# denuncias_2018_07: True
# denuncias_2019_01: True
# denuncias_2019_05: True
# denuncias_2017: False
# denuncias_2018_01: False
# denuncias_2018_06: False
# denuncias_2018_07: True
# denuncias_2019_01: True
# denuncias_2019_05: False
# denuncias_2017: False
# denuncias_2018_01: False
# denuncias_2018_06: False
# denuncias_2018_07: True
# denuncias_2019_01: True
# denuncias_2019_05: False
# denuncias_2017: False
# denuncias_2018_01: False
# denuncias_2018_06: False
# denuncias_2018_07: False
# denuncias_2019_01: False
# denuncias_2019_05: True
# denuncias_2017: False
# denuncias_2018_01: False
# denuncias_2018_06: False
# denuncias_2018_07: False
# denuncias_2019_01: False
# denuncias_2019_05: True
# denuncias_2017: False
# denuncias_2018_01: False
# denuncias_2018_06: False
# denuncias_2018_07: False
# denuncias_2019_01: False
# denuncias_2019_05: True
# denuncias_2017: False
# denuncias_2018_01: False
# denuncias_2018_06: False
# denuncias_2018_07: False
# denuncias_2019_01: False
# denuncias_2019_05: True

# %%
name_changes = {'denunciante_tipo_acercamiento':'acercamiento_tipo', 
                     'hecho_denuncia_previa':'denuncia_previa', 
                     'derivacion_judicializacion_organismo':'derivacion_organismo', 
                     'derivacion_judicializacion_fecha':'derivacion_fecha', 
                     'victima_genero': 'victima_identificada_genero', 
                     'victima_rango_etario':'victima_identificada_rango_etario', 
                     'victima_discapacidad':'victima_identificada_discapacidad', 
                     'victima_embarazada':'victima_identificada_embarazada', 
                     'victima_provincia_origen':'victima_identificada_provincia_origen', 
                     'victima_provincia_origen_indec_id':'victima_identificada_provincia_origen_id', 
                     'victima_nacionalidad':'victima_identificada_nacionalidad',
                     'llamante_provincia_indec_id':'llamante_provincia_id',
                     'victimas_estimadas_provincia_hecho_indec_id':'victimas_estimadas_provincia_hecho_id', 
                     'denunciado_provincia_indec_id':'denunciado_provincia_id'}

# A partir de 2018_07 empiezan a diferenciar entre victimas identificadas y estimadas
# Mejor hacer una columna identificada: True/False y que las variables embarazada/genero/etc apliquen 
# a ambos casos, a menos que me esté perdiendo algo? Puede haber victimas identificadas y embarazadas en un mismo caso?
# Sera que en la planilla original tenian los nombres de algunas, luego cuando publican los datos los anonimizan y separan 
# las columnas oentre identificadas y no? O los registraban asi de una?

# Iteramos sobre los dfs y estandarizamos los nombres de las columnas, agregando NaN para las rows que no tienen valores
# podría meter todo lo de abajo en un for que itera sobre los dfs

final_cols = ['denuncia_fecha', 'denuncia_previa', 'derivacion_seguimiento', 'llamante_anonimo', 
                    'llamante_genero', 'llamante_rango_etario', 'llamante_provincia', 'llamante_provincia_indec_id', 
                    'llamante_es_victima', 'denuncia_tipo_explotacion', 'denuncia_via_ingreso', 
                    'denunciante_tipo_acercamiento', 'hecho_localidad', 'hecho_provincia', 'hecho_provincia_indec_id', 
                    'hecho_pais', 'hecho_denuncia_previa', 'derivacion_judicializacion_organismo', 
                    'derivacion_judicializacion_fecha', 'victima_genero', 'victima_rango_etario', 'victima_discapacidad', 
                    'victima_embarazada', 'victima_provincia_origen','victima_provincia_origen_indec_id', 
                    'victima_cantidad', 'victima_nacionalidad', 'victimas_estimadas_cantidad','victimas_estimadas_genero', 
                    'victimas_estimadas_rango_etario', 'victimas_estimadas_provincia_hecho', 
                    'victimas_estimadas_provincia_hecho_indec_id', 'denunciado_genero', 'denunciado_rango_etario', 
                    'denunciado_provincia', 'denunciado_provincia_indec_id', 'connivencia_fuerzas_seguridad', 
                    'connivencia_poder_politico']


# estandarizamos los nombres

for df in denuncias:
    old_cols = df.columns.tolist()
    for col in old_cols:
        if col in name_changes:
            new_name = name_changes[col]
            df.rename(columns = {col: new_name}, inplace = True)
        
# chequear si esta bien transformar vicitma_genero en victima_identificada_genero etc a partir de 2017

denuncias = pd.concat([denuncias_2017, denuncias_2018_01, denuncias_2018_02, denuncias_2018_03, 
             denuncias_2018_04, denuncias_2018_05, denuncias_2018_06, denuncias_2018_07,
             denuncias_2018_08, denuncias_2018_09, denuncias_2018_10, denuncias_2018_11,
             denuncias_2018_12, denuncias_2019_01, denuncias_2019_02, denuncias_2019_03,
             denuncias_2019_04, denuncias_2019_05, denuncias_2019_06, denuncias_2019_07,
             denuncias_2019_08, denuncias_2019_09, denuncias_2019_10], sort=False, ignore_index=True)

denuncias = denuncias.drop(columns=['victimas_estimadas_provincia_hecho_id', 'victima_identificada_provincia_origen_id', 'denunciado_provincia_id', 'llamante_provincia_id'])

display(denuncias)
# Out:
#      denuncia_fecha        denuncia_tipo_explotacion denuncia_via_ingreso  \
# 0        2017-01-01               Explotación sexual            Línea 145
# 1        2017-01-01               Explotación sexual            Línea 145
# 2        2017-01-01               Explotación sexual            Línea 145
# 3        2017-01-01                     Desaparición            Línea 145
# 4        2017-01-01               Explotación sexual            Línea 145
# ...             ...                              ...                  ...
# 6517     2019-10-31  Explotación Laboral de N, N y A            Línea 145
# 6518     2019-10-31          Oferta Laboral Engañosa            Línea 145
# 6519     2019-10-31         Desaparición de personas            Línea 145
# 6520     2019-10-31              Explotación Laboral            Línea 145
# 6521     2019-10-30          Oferta Laboral Engañosa            Línea 145
#
#      acercamiento_tipo    hecho_localidad hecho_provincia hecho_pais  \
# 0                Otros  BARRIO SAENZ PEÑA        Santa Fe  Argentina
# 1                Otros            CORDOBA         Córdoba  Argentina
# 2                Otros            TUCUMAN         Tucumán  Argentina
# 3           Televisión             MORENO    Buenos Aires  Argentina
# 4                Otros         CONCEPCION         Tucumán  Argentina
# ...                ...                ...             ...        ...
# 6517             NS/NC                NaN             NaN        NaN
# 6518      Boca en Boca                NaN             NaN        NaN
# 6519             NS/NC                NaN             NaN        NaN
# 6520             NS/NC                NaN             NaN        NaN
# 6521      Boca en Boca                NaN             NaN        NaN
#
#      denuncia_previa                     derivacion_organismo  \
# 0                NaN                                   Protex
# 1                NaN                                   Protex
# 2                NaN                                   Protex
# 3                NaN  Protex - Fuerzas de seguridad federales
# 4                NaN  Protex - Fuerzas de seguridad federales
# ...              ...                                      ...
# 6517           Nueva                     Gendarmería y Protex
# 6518           Nueva             Area Legal para judicializar
# 6519           Nueva            Protex y Personas Extraviadas
# 6520           Nueva                     Gendarmería y Protex
# 6521           Nueva             Area Legal para judicializar
#
#      derivacion_fecha  ... denunciado_provincia connivencia_fuerzas_seguridad  \
# 0          2017-01-01  ...                  NaN                           NaN
# 1          2017-01-01  ...                  NaN                           NaN
# 2          2017-01-01  ...                  NaN                           NaN
# 3          2017-01-01  ...                  NaN                           NaN
# 4          2017-01-01  ...                  NaN                           NaN
# ...               ...  ...                  ...                           ...
# 6517       2019-10-31  ...                Salta                            No
# 6518       2019-10-31  ...                NS/NC                            No
# 6519       2019-10-31  ...                NS/NC                            No
# 6520       2019-10-31  ...                NS/NC                            No
# 6521       2019-10-31  ...                NS/NC                            No
#
#      connivencia_poder_politico hecho_provincia_indec_id  \
# 0                           NaN                      NaN
# 1                           NaN                      NaN
# 2                           NaN                      NaN
# 3                           NaN                      NaN
# 4                           NaN                      NaN
# ...                         ...                      ...
# 6517                         No                      NaN
# 6518                         No                      NaN
# 6519                         No                      NaN
# 6520                         No                      NaN
# 6521                         No                      NaN
#
#      denunciado_rango_etario victimas_estimadas_cantidad  \
# 0                        NaN                         NaN
# 1                        NaN                         NaN
# 2                        NaN                         NaN
# 3                        NaN                         NaN
# 4                        NaN                         NaN
# ...                      ...                         ...
# 6517                   NS/NC                           1
# 6518                   NS/NC                           1
# 6519                   NS/NC                           1
# 6520                   NS/NC                           9
# 6521                   NS/NC                       NS/NC
#
#      victimas_estimadas_genero victimas_estimadas_rango_etario  \
# 0                          NaN                             NaN
# 1                          NaN                             NaN
# 2                          NaN                             NaN
# 3                          NaN                             NaN
# 4                          NaN                             NaN
# ...                        ...                             ...
# 6517                 Masculino                              10
# 6518                  Femenino                              20
# 6519                 Masculino                              20
# 6520        Presencia de M y H                           NS/NC
# 6521                  Femenino                           NS/NC
#
#      victimas_estimadas_provincia_hecho  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ...                                 ...
# 6517                              Salta
# 6518                               CABA
# 6519                       Buenos Aires
# 6520                       Buenos Aires
# 6521                       Buenos Aires
#
#      victima_identificada_provincia_origen_indec_id
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 6517                                            NaN
# 6518                                            NaN
# 6519                                            NaN
# 6520                                            NaN
# 6521                                            NaN
#
# [6522 rows x 34 columns]

# %% [markdown]
# ## Limpieza columna por columna
# ### denunciado_rango_etario

# %%
#estos son strings. con regex elegir las rows q no tengan ninguna letra, convertirlas a int, calcular rango y pasarlo
# a la strig correspondiente.

#0 a 13
#14 a 16
#18 a 25
#26 a 40
#41 a 50
#51 a 60 
#61 en adelante
#no hay 16 a 18??
        
#Despues de haber pasado todo a strings, pasar el tipo de columna a "categorial"

for index, row in denuncias['denunciado_rango_etario'].iteritems():
    # ignore NaNs:
    if row != row:
        pass
    elif len(row) == 2:
        if int(row) <= 14:
            denuncias.replace(row, '0 a 13', inplace=True)
        elif 14 < int(row) <= 18:
            denuncias.replace(row, '14 a 16', inplace=True)
        elif 16 < int(row) <= 18:
            denuncias.replace(row, '16 a 17 (específico para trabajo adolescente)', inplace=True)
        elif 18 < int(row) <= 25:
            denuncias.replace(row, '18 a 25', inplace=True)
        elif 25 < int(row) <= 40:
            denuncias.replace(row, '26 a 40', inplace=True)
        elif 40 < int(row) <= 60:
            denuncias.replace(row, '41 a 60', inplace=True)
        elif int(row) >= 61:
            denuncias.replace(row, '61 en adelante', inplace=True)
        else:
            print(row)
            

print(denuncias['denunciado_rango_etario'].value_counts().head(30))
# Out:
# NS/NC                                            1200
# No sabe/no contesta                               721
# 26 a 40                                           299
# 41 a 60                                           267
# 18 a 25                                            66
# 61 en adelante                                     60
# 14 a 16                                            56
# No refiere                                         39
# 0 a 13                                             28
# ns/nc                                               6
# 16 a 17 (específico para trabajo adolescente)       5
# nS/NC                                               2
# Ns/Nc                                               2
# 14 a 15                                             1
# Sin datos                                           1
# NS/NC                                               1
# 1                                                   1
# Ns/NC                                               1
# Name: denunciado_rango_etario, dtype: int64

# %%
# Estandarizamos el No sabe/No contesta

denuncias['denunciado_rango_etario'].replace(to_replace='[Nn][Ss]/[Nn][Cc]', value='No sabe/no contesta', regex=True, inplace=True)

print(denuncias['denunciado_rango_etario'].value_counts())
# Out:
# No sabe/no contesta                              1932
# 26 a 40                                           299
# 41 a 60                                           267
# 18 a 25                                            66
# 61 en adelante                                     60
# 14 a 16                                            56
# No refiere                                         39
# 0 a 13                                             28
# 16 a 17 (específico para trabajo adolescente)       5
# Sin datos                                           1
# 14 a 15                                             1
# 1                                                   1
# No sabe/no contesta                                 1
# Name: denunciado_rango_etario, dtype: int64

# %%
# Quedan algunos cabos sueltos, que manejamos individualmente

denuncias['denunciado_rango_etario'].replace('1', 'No refiere', inplace=True)
denuncias['denunciado_rango_etario'].replace('Sin datos', 'No refiere', inplace=True)
denuncias['denunciado_rango_etario'].replace('14 a 15', '14 a 16', inplace=True)
denuncias['denunciado_rango_etario'].replace('No sabe/no contesta ', 'No sabe/no contesta', inplace=True)

print(denuncias['denunciado_rango_etario'].value_counts())
# Out:
# No sabe/no contesta                              1933
# 26 a 40                                           299
# 41 a 60                                           267
# 18 a 25                                            66
# 61 en adelante                                     60
# 14 a 16                                            57
# No refiere                                         41
# 0 a 13                                             28
# 16 a 17 (específico para trabajo adolescente)       5
# Name: denunciado_rango_etario, dtype: int64

# %% [markdown]
# ### denuncia_previa

# %%
denuncias['denuncia_previa'].replace(to_replace='[Nn][Uu][Ee][Vv][Aa]', value='Nueva', regex=True, inplace=True)
denuncias['denuncia_previa'].replace('Ampliatoria ', 'Ampliatoria', inplace=True)
denuncias['denuncia_previa'].replace('ampliatoria', 'Ampliatoria', inplace=True)
denuncias['denuncia_previa'].replace('RELACIONADA', 'Relacionada', inplace=True)
denuncias['denuncia_previa'].replace('relacionada', 'Relacionada', inplace=True)
denuncias['denuncia_previa'].replace(' ', 'Sin datos', inplace=True)

#Qué significa el valor "sí"?? No indica si es nueva, relacionada, ampliatoria, etc
denuncias['denuncia_previa'].value_counts()
# Out:
# No                                               1403
# Nueva                                            1044
# Sí                                                889
# Ampliatoria                                       359
# Relacionada                                       182
# Sin datos                                         168
# Amplía y está relacionada con otras Denuncias      28
# Name: denuncia_previa, dtype: int64

# %%
denuncias['derivacion_seguimiento'].replace(to_replace='[Nn][Oo]', value='No', regex=True, inplace=True)
denuncias['derivacion_seguimiento'].value_counts()
# Out:
# No           3578
# Sí            106
# Sin datos       2
# Name: derivacion_seguimiento, dtype: int64

# %%
denuncias['llamante_anonimo'].replace(to_replace='No ', value='No', regex=True, inplace=True)
denuncias['llamante_anonimo'].replace(to_replace='sí', value='Sí', regex=True, inplace=True)
denuncias['llamante_anonimo'].replace(to_replace='Anónima', value='Sí', regex=True, inplace=True)
denuncias['llamante_anonimo'].value_counts()

#Explorar Sin Datos para ver si las columnas de datos del llamante están vacías. En ese caso, transformar a 'Sí'
# Out:
# No           1977
# Sí           1708
# Sin datos       2
# Name: llamante_anonimo, dtype: int64

# %%
denuncias['llamante_genero'].replace(to_replace='FEMENINO', value='Femenino', inplace=True)
denuncias['llamante_genero'].replace(to_replace='femenino', value='Femenino', inplace=True)
denuncias['llamante_genero'].replace(to_replace='masculino', value='Masculino', inplace=True)
denuncias['llamante_genero'].replace(to_replace='MASCULINO', value='Masculino', inplace=True)
denuncias['llamante_genero'].replace(to_replace='NS/NC', value='No sabe/no contesta', inplace=True)
denuncias['llamante_genero'].replace(to_replace='Situaciones con hombres y mujeres o trans (varios)', value='Otros', inplace=True)

denuncias['llamante_genero'].value_counts()
# Que serían 'Situaciones'???? Supongo que hay varias personas llamando para denunciar, de distintos generos.. Sería Otros
# Out:
# Femenino               1818
# Masculino               903
# No sabe/no contesta     758
# Sin datos               200
# Otros                     4
# Trans                     4
# Name: llamante_genero, dtype: int64

# %%
for index, row in denuncias['llamante_rango_etario'].iteritems():
    # ignore NaNs:
    if row != row:
        pass
    elif len(row) == 2:
        if int(row) <= 14:
            denuncias.replace(row, '0 a 13', inplace=True)
        elif 14 < int(row) <= 18:
            denuncias.replace(row, '14 a 16', inplace=True)
        elif 16 < int(row) <= 18:
            denuncias.replace(row, '16 a 17 (específico para trabajo adolescente)', inplace=True)
        elif 18 < int(row) <= 25:
            denuncias.replace(row, '18 a 25', inplace=True)
        elif 25 < int(row) <= 40:
            denuncias.replace(row, '26 a 40', inplace=True)
        elif 40 < int(row) <= 60:
            denuncias.replace(row, '41 a 60', inplace=True)
        elif int(row) >= 61:
            denuncias.replace(row, '61 en adelante', inplace=True)
        else:
            print(row)
            
            
denuncias['llamante_rango_etario'].replace(to_replace='[Nn][Ss]/[Nn][Cc]', value='No sabe/no contesta', regex=True, inplace=True)
            
print(denuncias['llamante_rango_etario'].value_counts())

# Tiene sentido tener "No refiere" y "Sin datos"?
# Out:
# No sabe/no contesta                              1882
# 0 a 13                                            630
# 14 a 16                                           406
# 26 a 40                                           295
# 41 a 60                                           223
# 18 a 25                                           170
# 61 en adelante                                     44
# No refiere                                         27
# 16 a 17 (específico para trabajo adolescente)       8
# Sin datos                                           2
# Name: llamante_rango_etario, dtype: int64

# %%
denuncias['llamante_provincia'].replace('BUENOS AIRES', 'Buenos Aires', inplace=True)
denuncias['llamante_provincia'].replace('Buenos aires', 'Buenos Aires', inplace=True)
denuncias['llamante_provincia'].replace('CABA', 'Ciudad Autónoma de Buenos Aires', inplace=True)
denuncias['llamante_provincia'].replace('Caba', 'Ciudad Autónoma de Buenos Aires', inplace=True)
denuncias['llamante_provincia'].replace('caba', 'Ciudad Autónoma de Buenos Aires', inplace=True)
denuncias['llamante_provincia'].replace('cABA', 'Ciudad Autónoma de Buenos Aires', inplace=True)
denuncias['llamante_provincia'].replace('CHACO', 'Chaco', inplace=True)
denuncias['llamante_provincia'].replace('chubut', 'Chubut', inplace=True)
denuncias['llamante_provincia'].replace('CHUBUT', 'Chubut', inplace=True)
denuncias['llamante_provincia'].replace('CÓRDOBA', 'Córdoba', inplace=True)
denuncias['llamante_provincia'].replace('CORRIENTES', 'Corrientes', inplace=True)
denuncias['llamante_provincia'].replace('LA RIOJA', 'La Rioja', inplace=True)
denuncias['llamante_provincia'].replace('MENDOZA', 'Mendoza', inplace=True)
denuncias['llamante_provincia'].replace('mendoza', 'Mendoza', inplace=True)
denuncias['llamante_provincia'].replace('SALTA', 'Salta', inplace=True)
denuncias['llamante_provincia'].replace('salta', 'Salta', inplace=True)
denuncias['llamante_provincia'].replace('SANTA FE', 'Santa Fe', inplace=True)
denuncias['llamante_provincia'].replace('santa fe', 'Santa Fe', inplace=True)
denuncias['llamante_provincia'].replace('Santa fe', 'Santa Fe', inplace=True)
denuncias['llamante_provincia'].replace('Santiado del Estero', 'Santiago del Estero', inplace=True)
denuncias['llamante_provincia'].replace('TIERRA DEL FUEGO', 'Tierra del Fuego', inplace=True)
denuncias['llamante_provincia'].replace('NS/NC', 'No sabe/No contesta', inplace=True)
denuncias['llamante_provincia'].replace('Sin datos', 'No sabe/No contesta', inplace=True)
denuncias['llamante_provincia'].replace('Sin dato/no contesta', 'No sabe/No contesta', inplace=True)
denuncias['llamante_provincia'].replace('Internet', 'No sabe/No contesta', inplace=True)
denuncias['llamante_provincia'].replace('Otro país donde ocurre el hecho', 'País extranjero', inplace=True)


denuncias['llamante_provincia'].value_counts()
# Out:
# No sabe/No contesta                940
# Buenos Aires                       775
# Ciudad Autónoma de Buenos Aires    568
# Córdoba                            238
# Chubut                             206
# Santa Fe                           143
# Mendoza                            141
# Chaco                              117
# Salta                               78
# Corrientes                          67
# Tucumán                             66
# Neuquén                             56
# Misiones                            54
# Entre Ríos                          51
# Río Negro                           36
# Jujuy                               35
# Santiago del Estero                 27
# Catamarca                           18
# Tierra del Fuego                    17
# Formosa                             14
# San Juan                            11
# San Luis                             8
# Santa Cruz                           8
# La Rioja                             6
# La Pampa                             5
# País extranjero                      2
# Name: llamante_provincia, dtype: int64

# %%
denuncias['llamante_es_victima'].replace('No es Víctima', 'No es víctima', inplace=True)
denuncias['llamante_es_victima'].replace('no es Víctima', 'No es víctima', inplace=True)
denuncias['llamante_es_victima'].replace('no es víctima', 'No es víctima', inplace=True)
denuncias['llamante_es_victima'].replace('VÍCTIMA DIRECTA', 'Sí - Víctima directa', inplace=True)
denuncias['llamante_es_victima'].replace('Víctima Directa', 'Sí - Víctima directa', inplace=True)
denuncias['llamante_es_victima'].replace('Víctima Indirecta', 'Sí - Víctima indirecta', inplace=True)
denuncias['llamante_es_victima'].replace('No es víctima', 'No', inplace=True)

denuncias['llamante_es_victima'].value_counts()
# Out:
# No                        2169
# Sin datos                  750
# Sí                         431
# Sí - Víctima directa       262
# Sí - Víctima indirecta      75
# Name: llamante_es_victima, dtype: int64

# %%
denuncias['denuncia_tipo_explotacion'].replace('Explotación Sexual', 'Explotación sexual', inplace=True)
denuncias['denuncia_tipo_explotacion'].replace('EXPLOTACIÓN SEXUAL', 'Explotación sexual', inplace=True)
denuncias['denuncia_tipo_explotacion'].replace('explotación sexual', 'Explotación sexual', inplace=True)
denuncias['denuncia_tipo_explotacion'].replace('Eplotacion  Sexual ', 'Explotación sexual', inplace=True)
denuncias['denuncia_tipo_explotacion'].replace('Exploacion Sexual', 'Explotación sexual', inplace=True)
denuncias['denuncia_tipo_explotacion'].replace('Pornografía Infantil', 'Pornografía infantil', inplace=True)
denuncias['denuncia_tipo_explotacion'].replace('Posible Captación', 'Posible captación', inplace=True)
denuncias['denuncia_tipo_explotacion'].replace('OFERTA LABORAL ENGAÑOSA', 'Oferta laboral engañosa', inplace=True)
denuncias['denuncia_tipo_explotacion'].replace('Oferta Laboral Engañosa', 'Oferta laboral engañosa', inplace=True)
denuncias['denuncia_tipo_explotacion'].replace('oferta laboral engañosa', 'Oferta laboral engañosa', inplace=True)
denuncias['denuncia_tipo_explotacion'].replace('Explotación Laboral', 'Explotación laboral', inplace=True)
denuncias['denuncia_tipo_explotacion'].replace('Explotación Laboral de N, N y A', 'Explotación laboral de niñas, niños y adolescentes', inplace=True)
denuncias['denuncia_tipo_explotacion'].replace('Explotación Sexual de N, N y A', 'Explotación sexual de niñas, niños y adolescentes', inplace=True)
denuncias['denuncia_tipo_explotacion'].replace('Explotación sexual niñas, niños y adolescentes', 'Explotación sexual de niñas, niños y adolescentes', inplace=True)
denuncias['denuncia_tipo_explotacion'].replace('Explotación laboral niñas, niños y adolescentes', 'Explotación laboral de niñas, niños y adolescentes', inplace=True)
denuncias['denuncia_tipo_explotacion'].replace('NS/NC', 'Sin datos', inplace=True)
denuncias['denuncia_tipo_explotacion'].replace('Indicadores de Posible Trata de Personas', 'Posible trata de personas (hecho indefinido) ', inplace=True)
#Consultar si este último reemplazo es criterioso

denuncias['denuncia_tipo_explotacion'].value_counts()
# Out:
# Explotación sexual                                                                2886
# Desaparición                                                                       832
# Explotación laboral                                                                738
# Posible captación                                                                  596
# Oferta laboral engañosa                                                            246
# Secuestro/Venta de niños/pornografía infantil                                      240
# Posible trata de personas (hecho indefinido)                                       190
# Desaparición de personas                                                           147
# Publicidad de oferta sexual                                                         87
# Explotación sexual de niñas, niños y adolescentes                                   83
# Traslado de personas                                                                71
# Venta de niños y otros delitos                                                      67
# Grooming                                                                            56
# Explotación laboral de niñas, niños y adolescentes                                  39
# Publicidad de Oferta Sexual                                                         36
# Pornografía infantil                                                                32
# Venta de Niñxs y otros delitos                                                      30
# Reducción a la servidumbre o situaciones análogas                                   25
# Explotación sexual  - secuestro/Venta de niños/pornografía infantil                  9
# Explotación sexual  - laboral                                                        8
# Ofrecimiento                                                                         8
# DESAPARICIÓN DE PERSONAS                                                             6
# Explotación sexual  - desaparición                                                   5
#  Indicadores de Posible Trata de Personas                                            5
# Publicidad de oferta sexual  - posible captación                                     4
# Traslado de personas  - secuestro/Venta de niños/pornografía infantil                4
# Servidumbre doméstica                                                                4
# Sin datos                                                                            3
# Matrimonio Forzoso                                                                   3
# Posible captación  - secuestro/Venta de niños/pornografía infantil                   3
# Oferta laboral engañosa  - posible captación                                         3
# Mula                                                                                 2
# Explotación sexual  - laboral  - secuestro/Venta de niños/pornografía infantil       2
# Explotación laboral  - secuestro/Venta de niños/pornografía infantil                 2
# POSIBLE CAPTACIÓN                                                                    1
# Explotación laboral  - oferta laboral engañosa                                       1
# Otros                                                                                1
# Matrimonio forzado                                                                   1
# Traslado de personas  - posible captación                                            1
# Extracción de órganos                                                                1
# Venta de niños/pornografía infantil                                                  1
# Name: denuncia_tipo_explotacion, dtype: int64

# %%
denuncias['denuncia_via_ingreso'].replace('LÍNEA 145', 'Línea 145', inplace=True)
denuncias['denuncia_via_ingreso'].value_counts()

# Llamadas realizadas por seguimiento == Seguimiento?
# Línea telefónica institucional == Teléfono institucional (no salientes)??
# Out:
# Línea 145                                5920
# Correo institucional                      330
# Correo Electrónico                        124
# Línea telefónica institucional             35
# Sin datos                                  27
# Teléfono institucional (no salientes)      20
# Llamadas salientes                         10
# Llamadas realizadas por seguimiento         9
# Línea 149                                   7
# Solicitud Institucional- Saliente           6
# Presencial                                  5
# Línea 145 y correo institucional            4
# Línea 149 - CENAVID                         3
# Seguimiento                                 1
# Radio                                       1
# No aplica                                   1
# Name: denuncia_via_ingreso, dtype: int64

# %%
denuncias['acercamiento_tipo'].replace('ONG-Organismos nacionales', 'ONG - Organismos nacionales', inplace=True)
denuncias['acercamiento_tipo'].replace('Boca en Boca', 'Boca en boca', inplace=True)
denuncias['acercamiento_tipo'].replace('Por contacto (boca en boca)', 'Boca en boca', inplace=True)
denuncias['acercamiento_tipo'].replace('´No se consultó', 'Sin datos', inplace=True)
denuncias['acercamiento_tipo'].replace('No se consultó', 'Sin datos', inplace=True)
denuncias['acercamiento_tipo'].replace('No contesta / No se consultó', 'Sin datos', inplace=True)
denuncias['acercamiento_tipo'].replace('No contesta / No se consultó', 'Sin datos', inplace=True)
denuncias['acercamiento_tipo'].replace(to_replace='[Nn][Ss]/[Nn][Cc]', value='No sabe/no contesta', regex=True, inplace=True)
denuncias['acercamiento_tipo'].replace('TV', 'Televisión', inplace=True)
denuncias['acercamiento_tipo'].replace('INTERNET', 'Internet', inplace=True)
denuncias['acercamiento_tipo'].replace('internet', 'Internet', inplace=True)
denuncias['acercamiento_tipo'].replace('radio', 'Radio', inplace=True)
denuncias['acercamiento_tipo'].replace('ONG – Org Nacionales', 'ONG - Organismos nacionales', inplace=True)
denuncias['acercamiento_tipo'].replace('Otros modos de acercamiento a la Línea', 'Otros', inplace=True)
denuncias['acercamiento_tipo'].replace('Campañas del Programa', 'Campañas del programa', inplace=True)

denuncias['acercamiento_tipo'].value_counts()
# Out:
# Otros                          2373
# No sabe/no contesta            1118
# ONG - Organismos nacionales     839
# Sin datos                       817
# Internet                        441
# Boca en boca                    429
# Televisión                      356
# Campañas del programa            85
# Radio                            44
# Capacitación                     20
# Name: acercamiento_tipo, dtype: int64

# %% [markdown]
# ### Columnas limpias:
# - 'denunciado_rango_etario'
# - 'denuncia_previa'
# - 'derivacion_seguimiento'
# - 'llamante_anonimo'
# - 'llamante_genero'
# - 'llamante_rango_etario'
# - 'llamante_provincia'
# - 'llamante_es_victima'
# - 'denuncia_tipo_explotacion' - Revisar
# - 'denuncia_via_ingreso'
# - 'acercamiento_tipo'
#
#
# ### Por limpiar:
# 'llamante_provincia_indec_id', 'hecho_localidad', 'hecho_provincia', 'hecho_provincia_indec_id', 'hecho_pais', 'hecho_denuncia_previa', 'derivacion_judicializacion_organismo', 'derivacion_judicializacion_fecha', 'victima_genero', 'victima_rango_etario', 'victima_discapacidad',  'victima_embarazada', 'victima_provincia_origen','victima_provincia_origen_indec_id',
# 'victima_cantidad', 'victima_nacionalidad', 'victimas_estimadas_cantidad','victimas_estimadas_genero',
# 'victimas_estimadas_rango_etario', 'victimas_estimadas_provincia_hecho', 'victimas_estimadas_provincia_hecho_indec_id', 'denunciado_genero', 'denunciado_rango_etario', 'denunciado_provincia', 'denunciado_provincia_indec_id', 'connivencia_fuerzas_seguridad', 'connivencia_poder_politico']

# %% [markdown]
# Hay dos tipos de datasets:
#
# - Denuncias
# - Orientaciones (para casos que no son trata)
#
# Nos interesan solamente las denuncias.
#
# ## Denuncias
#
# Los datasets están divididos por año y/o mes
#
# 2017 - Dataset anual
# 2018 - Datasets mensuales, 2018-01 a 2018-12
# 2019 - Datasets mensuales, 2019-01 a 2019-10 (no está completo todavía el año)
#
# Las columnas se fueron modificando a lo largo del tiempo, en general fue aumentando el número de columnas para sumar más información, algunas desaparecieron y otras cambiaron de nombre.
#
# ### 2017
#
# - 10 columnas
#  'denuncia_fecha',
#  'denuncia_tipo_explotacion',
#  'denuncia_via_ingreso',
#  'denunciante_tipo_acercamiento',
#  'hecho_localidad',
#  'hecho_provincia',
#  'hecho_pais',
#  'hecho_denuncia_previa',
#  'derivacion_judicializacion_organismo',
#  'derivacion_judicializacion_fecha'
#
# ### 2018-01
#
# 'denuncia_fecha' - Se mantiene
# 'denuncia_tipo_explotacion' - Se mantiene
# 'denuncia_via_ingreso' - Se mantiene
# 'denunciante_tipo_acercamiento' - Se transforma en 'acercamiento_tipo'
# 'hecho_localidad' - Desaparece
# 'hecho_provincia' - Se mantiene
# 'hecho_pais' - Desaparece
# 'hecho_denuncia_previa' se transforma en 'denuncia_previa'
# 'derivacion_judicializacion_organismo' se transforma en 'derivacion_organismo'
# 'derivacion_judicializacion_fecha' se transforma en 'derivacion_fecha'
#
# Aparecen columnas nuevas:
# 'connivencia_fuerzas_seguridad'
# 'connivencia_poder_politico'
# 'denunciado_genero'
# 'denunciado_provincia'
# 'denunciado_provincia_indec_id'
# 'derivacion_seguimiento'
# 'hecho_provincia_indec_id'
# 'llamante_anonimo'
# 'llamante_es_victima'
# 'llamante_genero'
# 'llamante_provincia'
# 'llamante_provincia_indec_id'
# 'llamante_rango_etario'
# 'victima_cantidad'
# 'victima_discapacidad'
# 'victima_embarazada'
# 'victima_genero'
# 'victima_nacionalidad'
# 'victima_provincia_origen'
# 'victima_provincia_origen_indec_id'
# 'victima_rango_etario'
#
# localizacion: se empieza a considerar no solamente en que provincia sucedio el hecho, sino de que provincia son los actores involucrados (victima y denunciado)
# se recaban mas datos del denunciado y de la victima
# se taguea la localizacion con una id del indec
# se empieza a registrar la connivencia con el poder politico y las fuerzas de seguridad\
# se registra como se acerco el denunciado a la victima
#
# ### 2018-06
#
# se suma 'denunciado_rango_etario'
#
#
# ### 2018-07
#
# Se diferencia a las víctimas entre 'identificadas' y 'estimadas'.
# Se suman:
#
# 'victima_identificada_discapacidad',
# 'victima_identificada_embarazada',
# 'victima_identificada_genero',
# 'victima_identificada_nacionalidad',
# 'victima_identificada_provincia_origen',
# 'victima_identificada_provincia_origen_indec_id',
# 'victima_identificada_rango_etario',
# 'victimas_estimadas_cantidad',
# 'victimas_estimadas_genero',
# 'victimas_estimadas_provincia_hecho',
# 'victimas_estimadas_provincia_hecho_indec_id',
# 'victimas_estimadas_rango_etario'
#
# ### 2019
#
# Se mantiene igual con respecto a 2018 los primeros meses. En 201905 cambian los nombres de las columnas para sacarles la palabra 'indec'. El contenido presumiblemente es el mismo (chequear).
# 'denunciado_provincia_id'y eliminan 'denunciado_provincia_indec_id'
# (probablemente sea un cambio de nombre)
# lo mismo con 'llamante_provincia_indec_id' y 'llamante_provincia_indec_id'
#
# - Chequear si los datos son iguales en las columnas que cambiaron de nombre antes de mergear
